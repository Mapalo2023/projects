# %% [markdown]
# <h1><center>Project 1: Exploratory Data Analysis of Airbnb Data</center></h1>

# %% [markdown]
# ![Airbnb Logo](data:image/png;base64,...)

# %% [markdown]
# <h2><center>Mapalo Lukashi, Student ID: 800759428</center></h2>

# %% [markdown]
# ## Table of Contents
#
# * [Introduction](#zero-bullet)
# * [Data Summary](#first- )
# * [Exploratory Data Analysis (EDA)](#second-bullet)
# * [Inference](#third-bullet)
# * [Conclusion](#fourth-bullet)
# * [References & Appendix](#fifth-bullet)

# %% [markdown]
# ## PART 1: Introduction <a class="anchor" id="zero-bullet"></a>

# %% [markdown]
# * Airbnb® is an American company operating an online marketplace for lodging, primarily for vacation rentals
#
# * The purpose of my study is to perform an exploratory data analysis of the dataset containing Airbnb® listings for  Armsterdum, a major city in the Netherlands.
#
# * **Reserach Question:** I aim to use various data visualizations to gain valuable insights on whether there are any discernible relationships between the price of a listing, its location, and its room type?
#
# * The analysis in this project has been carried out using a structured Python package I built called 'airbnb_analysis' comprising of various modules (summary.py, analysis.py and inference.py) and classes.
#
# * The structral order of my pythin package is as follows:
#
#
# >airbnb_analysis/
# │
# ├── __init__.py
# ├── data_summary/
# │   ├── __init__.py
# │   └── summary.py
# ├── exploratory_data_analysis/
# │   ├── __init__.py
# │   └── analysis.py
# ├── inference/
# │   ├── __init__.py
# │   └── inference.py
# └── tests/
#     ├── __init__.py
#     └── test_functions.py*

# %% [markdown]
# ### Dataset

# %% [markdown]
# I am working with a single datasets containing data sourced from [inside_airbnb](http://insideairbnb.com/get-the-data/) (Murray Cox).

# %%
# Importing Libraries
import pandas as pd
import numpy as np
from datetime import date
import matplotlib as mpl
import matplotlib.pyplot as plt
import warnings
import seaborn as sns

# Import the necessary classes from your package
from airbnb_analysis.data_summary.summary import DataSummary
from airbnb_analysis.exploratory_data_analysis.analysis import ExploratoryDataAnalysis
from airbnb_analysis.inference.inference import Inference

# %% [markdown]
# ## PART 2: Data Summary <a class="anchor" id="first-bullet"></a>

# %% [markdown]
# #Summary statistics were generated for both numerical and categorical variables to understand the basic distribution of data.

# %%
# first I Specified the data URL
data_url = 'https://raw.githubusercontent.com/Mapalo2023/yeshiva/main/listings.csv'

# %%
# Create instances of the classes
data_summary = DataSummary(data_url)
exploratory_data_analysis = ExploratoryDataAnalysis(data_url)
inference = Inference(data_url)

# %%
# Display the head of the dataset (first 5 records)
data_summary.display_head()
# Out:
#        id                                               name  host_id  \
# 0  761411  Condo in Amsterdam · ★4.74 · 1 bedroom · 1 bed...  4013546
# 1  768274  Rental unit in Amsterdam · ★4.83 · 1 bedroom ·...  3678216
# 2  768737  Boat in Amsterdam · ★4.82 · 1 bedroom · 1 bed ...  3877342
# 3  771217  Houseboat in Amsterdam · ★5.0 · 3 bedrooms · 3...  4068486
# 4  771343  Rental unit in Amsterdam · ★4.89 · 1 bedroom ·...  2313061
#
#   host_name  neighbourhood_group neighbourhood  latitude  longitude  \
# 0    Xsjong                  NaN    Noord-Oost  52.40164    4.95106
# 1     J & R                  NaN    Westerpark  52.38855    4.88521
# 2    Nicole                  NaN    Westerpark  52.37824    4.86826
# 3  Danielle                  NaN          Zuid  52.34091    4.84802
# 4    Marcel                  NaN  Centrum-West  52.37641    4.88303
#
#          room_type  price  minimum_nights  number_of_reviews last_review  \
# 0     Private room     61               3                303  2023-08-19
# 1  Entire home/apt    327               3                 78  2023-08-16
# 2     Private room    109               2                341  2023-08-24
# 3  Entire home/apt    290               3                 10  2019-01-02
# 4     Private room    150               1                699  2023-09-01
#
#    reviews_per_month  calculated_host_listings_count  availability_365  \
# 0               2.30                               2               272
# 1               0.64                               1                16
# 2               2.73                               3                29
# 3               0.11                               1                 0
# 4               6.62                               2               196
#
#    number_of_reviews_ltm                   license
# 0                     26  0363 D4AD DCF3 E72A 56A2
# 1                      6  0363 7A50 18E7 51D1 B7F9
# 2                     43      036396BE30827DDB9575
# 3                      0  0363 D807 AD6C 499A F871
# 4                    110  0363 8C61 E9B9 5582 913E

# %%
# Display the tail of the dataset (last 5 records)
data_summary.display_tail()
# Out:
#                       id                                               name  \
# 8381  971403658453358540  Rental unit in Amsterdam · ★New · 1 bedroom · ...
# 8382  971600466535392582  Home in Amsterdam · ★New · 3 bedrooms · 3 beds...
# 8383  971686543447319533  Rental unit in Amsterdam · ★New · 1 bedroom · ...
# 8384  971758168481363169  Hotel in Amsterdam · ★New · 1 bedroom · 1 bed ...
# 8385  972218247170836285  Condo in Amsterdam · ★New · 2 bedrooms · 1 bed...
#
#         host_id host_name  neighbourhood_group            neighbourhood  \
# 8381    6879236   Michiel                  NaN                Oud-Noord
# 8382  307559908     Chris                  NaN                Oud-Noord
# 8383  170194324      Yara                  NaN            Bos en Lommer
# 8384   55794534     David                  NaN             Centrum-West
# 8385    2876582     Doris                  NaN  De Pijp - Rivierenbuurt
#
#        latitude  longitude        room_type  price  minimum_nights  \
# 8381  52.394972   4.906180  Entire home/apt    250               3
# 8382  52.387880   4.911080  Entire home/apt    337               3
# 8383  52.386497   4.848041  Entire home/apt    135               6
# 8384  52.372431   4.894491     Private room    160               5
# 8385  52.342122   4.909411  Entire home/apt    211               7
#
#       number_of_reviews last_review  reviews_per_month  \
# 8381                  0         NaN                NaN
# 8382                  0         NaN                NaN
# 8383                  0         NaN                NaN
# 8384                  0         NaN                NaN
# 8385                  0         NaN                NaN
#
#       calculated_host_listings_count  availability_365  number_of_reviews_ltm  \
# 8381                               1                 9                      0
# 8382                               1               267                      0
# 8383                               1                13                      0
# 8384                               1                 6                      0
# 8385                               1                55                      0
#
#                        license
# 8381  0363 9080 FE38 A7CE E7B7
# 8382  0363 5639 0AD2 7A88 3FED
# 8383  0363 C287 34D9 EA25 9428
# 8384                    Exempt
# 8385  0363 2F20 4F53 FB57 2D7F

# %% [markdown]
# ### Checking for Missing / Invalid Data Values

# %%
#The output shows that the dataset contains 8386 rows and 18 columns.
print(data_summary.get_shape())
# Out:
# (8386, 18)

# %%
# This shows the missing value percentage per attribute
print(data_summary.missing_value_percent())
# Out:
# id                                  0.000000
# name                                0.000000
# host_id                             0.000000
# host_name                           0.000000
# neighbourhood_group               100.000000
# neighbourhood                       0.000000
# latitude                            0.000000
# longitude                           0.000000
# room_type                           0.000000
# price                               0.000000
# minimum_nights                      0.000000
# number_of_reviews                   0.000000
# last_review                         9.897448
# reviews_per_month                   9.897448
# calculated_host_listings_count      0.000000
# availability_365                    0.000000
# number_of_reviews_ltm               0.000000
# license                             0.214643
# dtype: float64

# %%
# A brief summary of the dataset I am working with
data_summary.data_info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8386 entries, 0 to 8385
# Data columns (total 18 columns):
#  #   Column                          Non-Null Count  Dtype
# ---  ------                          --------------  -----
#  0   id                              8386 non-null   int64
#  1   name                            8386 non-null   object
#  2   host_id                         8386 non-null   int64
#  3   host_name                       8386 non-null   object
#  4   neighbourhood_group             0 non-null      float64
#  5   neighbourhood                   8386 non-null   object
#  6   latitude                        8386 non-null   float64
#  7   longitude                       8386 non-null   float64
#  8   room_type                       8386 non-null   object
#  9   price                           8386 non-null   int64
#  10  minimum_nights                  8386 non-null   int64
#  11  number_of_reviews               8386 non-null   int64
#  12  last_review                     7556 non-null   object
#  13  reviews_per_month               7556 non-null   float64
#  14  calculated_host_listings_count  8386 non-null   int64
#  15  availability_365                8386 non-null   int64
#  16  number_of_reviews_ltm           8386 non-null   int64
#  17  license                         8368 non-null   object
# dtypes: float64(4), int64(8), object(6)
# memory usage: 1.2+ MB

# %%
print(data_summary.data_types())
# Out:
# id                                  int64
# name                               object
# host_id                             int64
# host_name                          object
# neighbourhood_group               float64
# neighbourhood                      object
# latitude                          float64
# longitude                         float64
# room_type                          object
# price                               int64
# minimum_nights                      int64
# number_of_reviews                   int64
# last_review                        object
# reviews_per_month                 float64
# calculated_host_listings_count      int64
# availability_365                    int64
# number_of_reviews_ltm               int64
# license                            object
# dtype: object

# %%
# Show the categorical variables descriptive statistics
data_summary.categorical_descriptive_statistics()
# Out:
#                                                      name host_name  \
# count                                                8386      8386
# unique                                               3715      3200
# top     Rental unit in Amsterdam · ★5.0 · 1 bedroom · ...    Thomas
# freq                                                  296        42
#
#                  neighbourhood        room_type last_review license
# count                     8386             8386        7556    8368
# unique                      22                4        1014    7288
# top     De Baarsjes - Oud-West  Entire home/apt  2023-08-28  Exempt
# freq                      1382             6477         358     609

# %%
# Shows the numerical variables descriptive statistics
data_summary.numerical_descriptive_statistics()
# Out:
#                  id       host_id  neighbourhood_group     latitude  \
# count  8.386000e+03  8.386000e+03                  0.0  8386.000000
# mean   2.973884e+17  1.077878e+08                  NaN    52.366603
# std    3.905819e+17  1.448316e+08                  NaN     0.017191
# min    2.818000e+03  3.159000e+03                  NaN    52.290340
# 25%    1.851464e+07  1.025536e+07                  NaN    52.355640
# 50%    4.242761e+07  3.642318e+07                  NaN    52.365769
# 75%    7.227894e+17  1.444334e+08                  NaN    52.376440
# max    9.722182e+17  5.349544e+08                  NaN    52.425159
#
#          longitude         price  minimum_nights  number_of_reviews  \
# count  8386.000000   8386.000000     8386.000000        8386.000000
# mean      4.889834    254.489864        5.046625          45.437753
# std       0.035403    395.468275       34.710395         107.352805
# min       4.755870     18.000000        1.000000           0.000000
# 25%       4.865501    150.000000        2.000000           3.000000
# 50%       4.887580    207.000000        3.000000          10.000000
# 75%       4.908708    300.000000        4.000000          36.000000
# max       5.026430  27857.000000     1001.000000        3199.000000
#
#        reviews_per_month  calculated_host_listings_count  availability_365  \
# count        7556.000000                     8386.000000       8386.000000
# mean            1.175696                        1.831624         82.825066
# std             2.253706                        2.857336        113.568083
# min             0.010000                        1.000000          0.000000
# 25%             0.270000                        1.000000          0.000000
# 50%             0.580000                        1.000000         18.000000
# 75%             1.240000                        1.000000        142.000000
# max           120.110000                       27.000000        365.000000
#
#        number_of_reviews_ltm
# count            8386.000000
# mean               10.848080
# std                30.815465
# min                 0.000000
# 25%                 0.000000
# 50%                 3.000000
# 75%                 8.000000
# max              1689.000000

# %% [markdown]
# ### My Dataset Summary Observations:__ Univariate Analysis
#
# * This is a type of pandas Dataframe*
#
# * Index ranges from 0-8385,meaning it has 8386 rows*
#
# * Total number of columns 18*
#
# * eight integer data types and 6 attributes are in object form and four are in float form,*
#
# * Dataset used computer memory 1.2+ Megabyte*
#
# * last_review and reviews_per_month have some null values, other attributes have no null values,*
#
# * PROPORTION OF last_review AMONG ALL Listings and reviews_per_month has 9.8% null values,*
# * neighbourhood_group has 100% null values*

# %% [markdown]
# ## PART 3: Exploratory Data Analysis <a class="anchor" id="second-bullet"></a>

# %% [markdown]
# EDA is crucial for understanding the distribution of data, identifying outliers, and discovering patterns. I began by examining the unique values and their counts for crucial categorical variables like neighbourhood and room_type.

# %%
# display unique values of 'neighbourhood'
exploratory_data_analysis.unique_neighbourhood()
# Out:
# array(['Noord-Oost', 'Westerpark', 'Zuid', 'Centrum-West', 'Slotervaart',
#        'Centrum-Oost', 'Oostelijk Havengebied - Indische Buurt',
#        'Buitenveldert - Zuidas', 'IJburg - Zeeburgereiland', 'Oud-Oost',
#        'De Pijp - Rivierenbuurt', 'De Baarsjes - Oud-West',
#        'Bos en Lommer', 'Watergraafsmeer', 'Oud-Noord', 'Noord-West',
#        'Geuzenveld - Slotermeer', 'De Aker - Nieuw Sloten', 'Osdorp',
#        'Bijlmer-Centrum', 'Gaasperdam - Driemond', 'Bijlmer-Oost'],
#       dtype=object)

# %%
# This code gets the value counts for the airbnb_listing neighbourhood value counts: 
#from the ouptut, Most appear to span the De Baarsjes - Oud-West  neighbourhood as mode_value
exploratory_data_analysis.neighbourhood_value_counts()
# Out:
# De Baarsjes - Oud-West                    1382
# Centrum-West                              1006
# De Pijp - Rivierenbuurt                    935
# Centrum-Oost                               793
# Zuid                                       599
# Westerpark                                 584
# Oud-Oost                                   506
# Bos en Lommer                              424
# Oud-Noord                                  402
# Oostelijk Havengebied - Indische Buurt     320
# Watergraafsmeer                            262
# Noord-West                                 218
# IJburg - Zeeburgereiland                   183
# Slotervaart                                164
# Noord-Oost                                 137
# Geuzenveld - Slotermeer                    116
# Buitenveldert - Zuidas                     100
# De Aker - Nieuw Sloten                      74
# Gaasperdam - Driemond                       51
# Bijlmer-Centrum                             47
# Osdorp                                      44
# Bijlmer-Oost                                39
# Name: neighbourhood, dtype: int64

# %%
# This code gets the value counts for the airbnb_listing room_type attribute:
# Most appear to span the Entire home/apt room_type (mode value)
print(exploratory_data_analysis.unique_room_type())
# Out:
# ['Private room' 'Entire home/apt' 'Hotel room' 'Shared room']

# %%
# This code gets the value counts for the airbnb_listing variable: Most appear to span the Entire home/apt room_type (mode value)
print(exploratory_data_analysis.room_type_value_counts())
# Out:
# Entire home/apt    6477
# Private room       1813
# Hotel room           54
# Shared room          42
# Name: room_type, dtype: int64

# %% [markdown]
# ### Analysing some categorical attributes

# %%
#Analysing the categorical attribute neighbourhood
exploratory_data_analysis.bar_plot_neighbourhood()

# %%
#Analysing the categorical attribute room_type
exploratory_data_analysis.bar_plot_room_type()

# %% [markdown]
# ### Analysing some numeric attributes

# %%
print(exploratory_data_analysis.price_describe())
# Out:
# count     8386.000000
# mean       254.489864
# std        395.468275
# min         18.000000
# 25%        150.000000
# 50%        207.000000
# 75%        300.000000
# max      27857.000000
# Name: price, dtype: float64

# %%
exploratory_data_analysis.minimum_nights_describe()
# Out:
# count    8386.000000
# mean        5.046625
# std        34.710395
# min         1.000000
# 25%         2.000000
# 50%         3.000000
# 75%         4.000000
# max      1001.000000
# Name: minimum_nights, dtype: float64

# %%
exploratory_data_analysis.number_of_reviews_describe()
# Out:
# count    8386.000000
# mean       45.437753
# std       107.352805
# min         0.000000
# 25%         3.000000
# 50%        10.000000
# 75%        36.000000
# max      3199.000000
# Name: number_of_reviews, dtype: float64

# %%
# Call the method to plot the price distribution with mathplotlib
exploratory_data_analysis.plot_price_distribution()

# %%
# Call the method to plot price distribution with Seaborn
exploratory_data_analysis.plot_price_distribution_seaborn()

# %%
exploratory_data_analysis.plot_minimum_nights_distribution()

# %%
# Call the method to plot the minimum_nights_distribution distribution with Seaborn
exploratory_data_analysis.plot_minimum_nights_distribution_seaborn()

# %%
# Call the method to plot the number of reviews distribution with mathplotlib
exploratory_data_analysis.plot_number_of_reviews_distribution()

# %%
# Call the method to plot the number of reviews distribution with Seaborn
exploratory_data_analysis.plot_number_of_reviews_distribution_seaborn()

# %% [markdown]
# ## PART 4: Inference <a class="anchor" id="third-bullet"></a>

# %% [markdown]
# ### Bivariate / Multi-variate Analysis

# %% [markdown]
# > #### minimum_nights (numeric) vs.Price (numeric)

# %%
# Call the method to plot the scatterplot number of _price vs minimum_nightsreviews distribution with mathplotlib
inference.scatter_plot_price_minimum_nights()

# %%
# Call the method to plot the scatterplot number of _price vs minimum_nightsreviews distribution with Seaborn
inference.scatter_plot_price_minimum_nights_seaborn()

# %% [markdown]
# >#### number of reviews (numeric) vs.Minimum nights(numeric)

# %%
# Call the method to plot the scatterplot minimum_nights vs number_of_reviews distribution with mathplotlib
inference.scatter_plot_minimum_nights_number_of_reviews()

# %%
# Call the method to plot the scatterplot minimum_nights vs number_of_reviews distribution with Seaborn
inference.scatter_plot_minimum_nights_number_of_reviews_seaborn()

# %% [markdown]
# >####   neighbourhood (categorical) vs. price (numeric)

# %%
inference.catplot_price_neighbourhood(figsize=(10, 6))

# %%
inference.catplot_price_room_type(figsize=(10, 6))

# %% [markdown]
# >#### neighbourhood (categorical) vs. room_type(categorial)

# %%
crosstab_result = inference.crosstab_room_type_neighbourhood()
crosstab_result
# Out:
# neighbourhood    Bijlmer-Centrum  Bijlmer-Oost  Bos en Lommer  \
# room_type
# Entire home/apt               25            22            380
# Hotel room                     0             0              0
# Private room                  22            17             42
# Shared room                    0             0              2
#
# neighbourhood    Buitenveldert - Zuidas  Centrum-Oost  Centrum-West  \
# room_type
# Entire home/apt                      67           524           598
# Hotel room                            0             4            14
# Private room                         33           256           387
# Shared room                           0             9             7
#
# neighbourhood    De Aker - Nieuw Sloten  De Baarsjes - Oud-West  \
# room_type
# Entire home/apt                      32                    1182
# Hotel room                            0                       7
# Private room                         41                     191
# Shared room                           1                       2
#
# neighbourhood    De Pijp - Rivierenbuurt  Gaasperdam - Driemond  ...  \
# room_type                                                        ...
# Entire home/apt                      808                     28  ...
# Hotel room                             2                      4  ...
# Private room                         124                     18  ...
# Shared room                            1                      1  ...
#
# neighbourhood    Noord-Oost  Noord-West  \
# room_type
# Entire home/apt          92         175
# Hotel room                0           2
# Private room             45          41
# Shared room               0           0
#
# neighbourhood    Oostelijk Havengebied - Indische Buurt  Osdorp  Oud-Noord  \
# room_type
# Entire home/apt                                     259      28        301
# Hotel room                                            0       0          4
# Private room                                         60      16         87
# Shared room                                           1       0         10
#
# neighbourhood    Oud-Oost  Slotervaart  Watergraafsmeer  Westerpark  Zuid
# room_type
# Entire home/apt       433          122              209         505   477
# Hotel room              7            1                0           2     7
# Private room           63           41               53          76   114
# Shared room             3            0                0           1     1
#
# [4 rows x 22 columns]

# %%
inference.plot_crosstab_bar()
# Out:
# <Axes: title={'center': 'Neighbourhood vs. Room Type'}, xlabel='room_type', ylabel='Count'>

# %% [markdown]
# ## Multivariate analysis
#
# >#### Price vs. neighbourhood vs. Room_type

# %%
g = inference.catplot_price_room_type_neighbourhood()

# %% [markdown]
# ## PART 5: Conclusion <a class="anchor" id="fourth-bullet"></a>

# %% [markdown]
# The analysis unearthed various insights into the distribution of Airbnb listings across different neighbourhoods, room types, and price ranges. It also highlighted the relationship between price, minimum nights, and number of reviews. These findings can be instrumental for hosts in setting competitive prices and for guests in making informed booking decisions.

# %% [markdown]
# ## PART 6: References <a class="anchor" id="fifth-bullet"></a>

# %% [markdown]
# Dataset: Airbnb Listings: http://insideairbnb.com/get-the-data/
#  <br>Libraries: Pandas, Matplotlib, Seaborn
